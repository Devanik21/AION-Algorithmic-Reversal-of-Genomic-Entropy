# %% [markdown]
# # Exploratory Data Analysis of AION Simulation Logs
#
# This notebook provides an initial analysis of population dynamics and entropy accumulation over time.

# %%
import pandas as pd
import matplotlib.pyplot as plt

print('Ready for analysis.')
